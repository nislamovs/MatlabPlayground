% %%
pkg load symbolic
syms x

f=(sin(x/2))^3
diff(f, x)
% Out:
% Symbolic pkg v3.1.1: Python communication link active, SymPy v1.5.1.
% f = (sym)
%
%      3⎛x⎞
%   sin ⎜─⎟
%       ⎝2⎠
%
% ans = (sym)
%
%        2⎛x⎞    ⎛x⎞
%   3⋅sin ⎜─⎟⋅cos⎜─⎟
%         ⎝2⎠    ⎝2⎠
%   ────────────────
%          2

% %%
graphics_toolkit("notebook")  % The default
sombrero
% Out:
% error: graphics_toolkit: notebook toolkit is not available
% error: called from
%     graphics_toolkit at line 81 column 5

% %%
sombrero

% %%
graphics_toolkit("plotly")

a = [1:0.1:13];
theta = linspace (0,2*pi,1000);
rho = sin (7*theta);

subplot(2,2,1);
sombrero()
grid on;
box on;

subplot(2,2,2);
plot(theta, rho);
grid on;
box on;

subplot(2,2,3);
polar(a,a)
grid on;
box on;

subplot(2,2,4);
polar(theta, rho);
grid on;
box on;
% Out:
% error: graphics_toolkit: plotly toolkit is not available
% error: called from
%     graphics_toolkit at line 81 column 5
